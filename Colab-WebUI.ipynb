# %% [markdown]
# <a href="https://colab.research.google.com/github/acikacik1314/two-bears-blog/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Overwriting /content/setup.sh

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### 2.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !pip install gradio==3.50.2
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting gradio==3.50.2
#   Downloading gradio-3.50.2-py3-none-any.whl.metadata (17 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.50.2)
#   Using cached aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (5.0.1)
# Collecting fastapi (from gradio==3.50.2)
#   Using cached fastapi-0.139.2-py3-none-any.whl.metadata (26 kB)
# Collecting ffmpy (from gradio==3.50.2)
#   Using cached ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==0.6.1 (from gradio==3.50.2)
#   Downloading gradio_client-0.6.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (0.27.0)
# Collecting huggingface-hub>=0.14.0 (from gradio==3.50.2)
#   Using cached huggingface_hub-1.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio==3.50.2)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (3.9.2)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (1.26.4)
# Collecting orjson~=3.0 (from gradio==3.50.2)
#   Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (10.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (2.8.2)
# Collecting pydub (from gradio==3.50.2)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart (from gradio==3.50.2)
#   Using cached python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (2.32.3)
# Collecting semantic-version~=2.0 (from gradio==3.50.2)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/site-packages (from gradio==3.50.2) (4.11.0)
# Collecting uvicorn>=0.14.0 (from gradio==3.50.2)
#   Using cached uvicorn-0.51.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<12.0,>=10.0 (from gradio==3.50.2)
#   Downloading websockets-11.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/site-packages (from gradio-client==0.6.1->gradio==3.50.2) (2024.6.1)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==3.50.2) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio==3.50.2) (0.12.0)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub>=0.14.0->gradio==3.50.2)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub>=0.14.0->gradio==3.50.2) (3.13.1)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub>=0.14.0->gradio==3.50.2)
#   Using cached hf_xet-1.5.2-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/site-packages (from huggingface-hub>=0.14.0->gradio==3.50.2) (4.66.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx->gradio==3.50.2) (4.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/site-packages (from httpx->gradio==3.50.2) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx->gradio==3.50.2) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/site-packages (from httpx->gradio==3.50.2) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/site-packages (from httpx->gradio==3.50.2) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx->gradio==3.50.2) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib~=3.0->gradio==3.50.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==3.50.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio==3.50.2) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.50.2) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.50.2) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests~=2.0->gradio==3.50.2) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests~=2.0->gradio==3.50.2) (2.2.3)
# Collecting starlette>=0.46.0 (from fastapi->gradio==3.50.2)
#   Using cached starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 (from gradio==3.50.2)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi->gradio==3.50.2)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->gradio==3.50.2)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting pydantic-core==2.46.4 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.50.2)
#   Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions~=4.0 (from gradio==3.50.2)
#   Using cached typing_extensions-4.16.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (0.10.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==3.50.2) (1.16.0)
# Downloading gradio-3.50.2-py3-none-any.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 114.8 MB/s eta 0:00:00
# Downloading gradio_client-0.6.1-py3-none-any.whl (299 kB)
# Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading huggingface_hub-1.24.0-py3-none-any.whl (771 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 30.8 MB/s eta 0:00:00
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (134 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading uvicorn-0.51.0-py3-none-any.whl (73 kB)
# Downloading websockets-11.0.3-py3-none-any.whl (118 kB)
# Using cached fastapi-0.139.2-py3-none-any.whl (130 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 64.8 MB/s eta 0:00:00
# Using cached typing_extensions-4.16.0-py3-none-any.whl (45 kB)
# Using cached ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Using cached python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached hf_xet-1.5.2-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.4 MB)
# Using cached starlette-1.3.1-py3-none-any.whl (73 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: pydub, websockets, typing-extensions, semantic-version, python-multipart, orjson, importlib-resources, hf-xet, ffmpy, click, annotated-doc, aiofiles, uvicorn, typing-inspection, starlette, pydantic-core, pydantic, huggingface-hub, gradio-client, fastapi, gradio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed aiofiles-23.2.1 annotated-doc-0.0.4 click-8.4.2 fastapi-0.139.2 ffmpy-1.0.0 gradio-3.50.2 gradio-client-0.6.1 hf-xet-1.5.2 huggingface-hub-1.24.0 importlib-resources-6.5.2 orjson-3.11.9 pydantic-2.13.4 pydantic-core-2.46.4 pydub-0.25.1 python-multipart-0.0.32 semantic-version-2.10.0 starlette-1.3.1 typing-extensions-4.16.0 typing-inspection-0.4.2 uvicorn-0.51.0 websockets-11.0.3
